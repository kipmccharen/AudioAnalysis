# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from spotipy.oauth2 import SpotifyOAuth
import urllib
from dotenv import load_dotenv
import pandas as pd
from pprint import pprint
import requests
import os 
import base64
import json

# %%
load_dotenv()

SpotifyClientID = os.getenv("SPOTIPY_CLIENT_ID")
SpotifyClientSecret = os.getenv("SPOTIPY_CLIENT_SECRET")
SpotifyRedirectURI = os.getenv("SPOTIPY_REDIRECT_URI")
SpotifyOath = os.getenv("SpotifyOath")

def _make_authorization_headers(client_id, client_secret):
    auth_header = base64.b64encode(
        f"{client_id}:{client_secret}".encode("ascii")
    )
    return {"Authorization": "Basic %s" % auth_header.decode("ascii")}

baseauth = _make_authorization_headers(SpotifyClientID, SpotifyClientSecret)

tok = requests.post(r"https://accounts.spotify.com/api/token", 
                   data={"grant_type": "client_credentials"},
                   headers=baseauth)
btok = json.loads(tok.content)['access_token']
bear = {"Authorization": f"Bearer {btok}"}
bear
# Out:
# {'Authorization': 'Bearer BQAAxwJ8dDTK3_ZFitbhfwkINstx8NwSxf_3HJAoCWjBslbqtvxPM1LRZ_NVEBCG3LiEe07afov9bS7QmxU'}

# %%
search_str = 'Avatar Soundtrack'
options = 'album,playlist'
q = urllib.parse.quote(search_str)
o = urllib.parse.quote(options)
getme = f"https://api.spotify.com/v1/search?query={q}" \
    + f"&type={o}&market=US&offset=0&limit=10"
getme
# Out:
# 'https://api.spotify.com/v1/search?query=Avatar%20Soundtrack&type=album%2Cplaylist&market=US&offset=0&limit=10'

# %%
output = requests.get(getme, headers=bear)
jl = json.loads(output.content)
#alb = jl['albums']['items']
ply = jl['playlists']['items']
df = pd.json_normalize(alb).append(pd.json_normalize(ply))
df
# Out:
#   album_type                                            artists  \
# 0      album  [{'external_urls': {'spotify': 'https://open.s...
# 1     single  [{'external_urls': {'spotify': 'https://open.s...
# 2      album  [{'external_urls': {'spotify': 'https://open.s...
# 3      album  [{'external_urls': {'spotify': 'https://open.s...
# 4      album  [{'external_urls': {'spotify': 'https://open.s...
# 5     single  [{'external_urls': {'spotify': 'https://open.s...
# 6     single  [{'external_urls': {'spotify': 'https://open.s...
# 7     single  [{'external_urls': {'spotify': 'https://open.s...
# 8     single  [{'external_urls': {'spotify': 'https://open.s...
# 9     single  [{'external_urls': {'spotify': 'https://open.s...
# 0        NaN                                                NaN
# 1        NaN                                                NaN
# 2        NaN                                                NaN
# 3        NaN                                                NaN
# 4        NaN                                                NaN
# 5        NaN                                                NaN
# 6        NaN                                                NaN
# 7        NaN                                                NaN
# 8        NaN                                                NaN
# 9        NaN                                                NaN
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/albums/3sxAbZWu0pwQ...  3sxAbZWu0pwQGhlGKuH7dn
# 1  https://api.spotify.com/v1/albums/1YlUiFkwWQlR...  1YlUiFkwWQlRPtTOWTCIfY
# 2  https://api.spotify.com/v1/albums/4TdAFjR0BVBj...  4TdAFjR0BVBjKNoqQSRWxY
# 3  https://api.spotify.com/v1/albums/6qQgLmmKuZEp...  6qQgLmmKuZEp8UeodNIBJQ
# 4  https://api.spotify.com/v1/albums/7pk5hCy3Bkfq...  7pk5hCy3Bkfqe3R4sSCf94
# 5  https://api.spotify.com/v1/albums/12BNYTgDsLqK...  12BNYTgDsLqKG4btRSuwiM
# 6  https://api.spotify.com/v1/albums/4DoIdM8E2QXt...  4DoIdM8E2QXthK3BOL9pne
# 7  https://api.spotify.com/v1/albums/0qsQIf5oWX1V...  0qsQIf5oWX1VDmDO11sYbq
# 8  https://api.spotify.com/v1/albums/03wTqWQ1dQOq...  03wTqWQ1dQOqPHW5nOxTuz
# 9  https://api.spotify.com/v1/albums/1bLpIaToKXuH...  1bLpIaToKXuHBhmFrrXMXJ
# 0  https://api.spotify.com/v1/playlists/7oIdYroGB...  7oIdYroGBOg5DZC4MtXZr7
# 1  https://api.spotify.com/v1/playlists/2WaqTt9se...  2WaqTt9seWhMkntDBaxQA0
# 2  https://api.spotify.com/v1/playlists/3bDOB6WgV...  3bDOB6WgVzAmFDhjKHtVq7
# 3  https://api.spotify.com/v1/playlists/2CaOL7cJe...  2CaOL7cJeAZzDQQqkxeD1x
# 4  https://api.spotify.com/v1/playlists/0i4e1HNsR...  0i4e1HNsRSuzR4PhZBTe1h
# 5  https://api.spotify.com/v1/playlists/1QHbLvsWl...  1QHbLvsWlJBXiT9GQQTdI7
# 6  https://api.spotify.com/v1/playlists/7el6VJ9QR...  7el6VJ9QRYF4D2cEekjEtI
# 7  https://api.spotify.com/v1/playlists/3lvqb63AM...  3lvqb63AMRGNUMezeTXij5
# 8  https://api.spotify.com/v1/playlists/2bGTu4LPo...  2bGTu4LPoSeYh0CHujHgyP
# 9  https://api.spotify.com/v1/playlists/3mpSeSzWj...  3mpSeSzWjdDDvHuueC0jQS
#
#                                               images  \
# 0  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 1  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 2  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 3  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 4  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 5  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 6  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 7  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 8  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 9  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 0  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 1  [{'height': 640, 'url': 'https://mosaic.scdn.c...
# 2  [{'height': None, 'url': 'https://i.scdn.co/im...
# 3  [{'height': 640, 'url': 'https://mosaic.scdn.c...
# 4  [{'height': 640, 'url': 'https://mosaic.scdn.c...
# 5  [{'height': None, 'url': 'https://i.scdn.co/im...
# 6  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 7  [{'height': 640, 'url': 'https://mosaic.scdn.c...
# 8  [{'height': None, 'url': 'https://i.scdn.co/im...
# 9  [{'height': 640, 'url': 'https://mosaic.scdn.c...
#
#                                                 name release_date  \
# 0  Ultima Forever: Quest for the Avatar, Pt. 1 (E...   2013-10-29
# 1  Avatar: Tla and Legend of Korra Piano Soundtra...   2013-06-30
# 2                 Avatar (The Soundtrack Highlights)   2014-08-20
# 3                     AVATAR 2 | Fan-Made Soundtrack         2018
# 4  The Last Avatar (Original Motion Picture Sound...   2014-12-05
# 5  Narsingh Avatar (Original Motion Picture Sound...   1949-01-01
# 6  Avatar of Darkness, Vol. 02 (Original Soundtrack)   2020-03-20
# 7               I See You Avatar (Avatar Soundtrack)   2019-04-10
# 8               I See You (Soundtrack from "Avatar")   2012-12-11
# 9                          I See You (From "Avatar")   2012-12-10
# 0                                  Avatar Soundtrack          NaN
# 1                               Avatar soundtracks 😍          NaN
# 2               Avatar The Last Airbender Soundtrack          NaN
# 3                             Epic Movie Soundtracks          NaN
# 4                     Avatar: The Last Airbender OST          NaN
# 5             avatar the last airbender "soundtrack"          NaN
# 6                            AVATAR Movie Soundtrack          NaN
# 7                 Inspirational scores & soundtracks          NaN
# 8                       The King's Avatar - OST 全职高手          NaN
# 9                                  Avatar Soundtrack          NaN
#
#   release_date_precision  total_tracks      type  ... public  \
# 0                    day          26.0     album  ...    NaN
# 1                    day           5.0     album  ...    NaN
# 2                    day          12.0     album  ...    NaN
# 3                   year           7.0     album  ...    NaN
# 4                    day          14.0     album  ...    NaN
# 5                    day           4.0     album  ...    NaN
# 6                    day           5.0     album  ...    NaN
# 7                    day           1.0     album  ...    NaN
# 8                    day           1.0     album  ...    NaN
# 9                    day           1.0     album  ...    NaN
# 0                    NaN           NaN  playlist  ...   None
# 1                    NaN           NaN  playlist  ...   None
# 2                    NaN           NaN  playlist  ...   None
# 3                    NaN           NaN  playlist  ...   None
# 4                    NaN           NaN  playlist  ...   None
# 5                    NaN           NaN  playlist  ...   None
# 6                    NaN           NaN  playlist  ...   None
# 7                    NaN           NaN  playlist  ...   None
# 8                    NaN           NaN  playlist  ...   None
# 9                    NaN           NaN  playlist  ...   None
#
#                                          snapshot_id  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
# 0  MixmYzU1MWIxMmExMWFlYzliYWU1Nzk0ZmE4NjVjNWI3ZD...
# 1  MjcsNTI2ZmVlZmQ2MzIwMjMzNGYwZjZkM2ZiNWRjNTBkMG...
# 2  NzYsNWFjMzJkYzkyM2JjOTk3OTBmNWViYjI3NGY4MjA1Y2...
# 3  MTc0LDQwMmFiMjYzNWMxMWI5NDQ4ZDA2ZDdjZTY2YTA5Mj...
# 4  MzgsNjlkMjJiMGQ4N2Q5MDE4NDhlY2MyNTU0NjdmMTcwZm...
# 5  NDUsODQwZjE3OTRjNjNhNWNiNTVlOGYzOWY5ZjZkOWQ2OW...
# 6  NCw5MDUyOWE2MTIxOGRkN2U0MzJjNzFkNjcxNmNhNDNmZG...
# 7  ODMwLDM0MzI4MzgxMTcyZmJjM2E3MGU4Mjc3ZDQwOTM2Ym...
# 8  MTUsM2E1MmY5OTVhZDljMGVkNGM3YmE1OWNlMmMzNmQ1Yz...
# 9  MTIsMTRhODgwYzIyZDY5MjE3YmE0ZDNhMzIyMGMwMDBkMj...
#
#          owner.display_name  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# 5                       NaN
# 6                       NaN
# 7                       NaN
# 8                       NaN
# 9                       NaN
# 0  Carol Villalón Deepdance
# 1           mozell billings
# 2                Samuel Kim
# 3             bradleywsmith
# 4           BeauTiFuL LoSeR
# 5           Taylor Mascetta
# 6              juttasurmann
# 7         Victoria Peechatt
# 8           Débora Favoreto
# 9                      leah
#
#                          owner.external_urls.spotify  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
# 0        https://open.spotify.com/user/elektroduenda
# 1  https://open.spotify.com/user/cxf8i84lez9qp5tx...
# 2  https://open.spotify.com/user/o90kk72f7l3kerpr...
# 3        https://open.spotify.com/user/bradleywsmith
# 4     https://open.spotify.com/user/jainaa._.yenserr
# 5          https://open.spotify.com/user/taytay92901
# 6         https://open.spotify.com/user/juttasurmann
# 7  https://open.spotify.com/user/22v66rfshydf744k...
# 8  https://open.spotify.com/user/53kzdh7uqp7otizf...
# 9  https://open.spotify.com/user/xom5ul5f9g6lxfco...
#
#                                           owner.href  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
# 0     https://api.spotify.com/v1/users/elektroduenda
# 1  https://api.spotify.com/v1/users/cxf8i84lez9qp...
# 2  https://api.spotify.com/v1/users/o90kk72f7l3ke...
# 3     https://api.spotify.com/v1/users/bradleywsmith
# 4  https://api.spotify.com/v1/users/jainaa._.yenserr
# 5       https://api.spotify.com/v1/users/taytay92901
# 6      https://api.spotify.com/v1/users/juttasurmann
# 7  https://api.spotify.com/v1/users/22v66rfshydf7...
# 8  https://api.spotify.com/v1/users/53kzdh7uqp7ot...
# 9  https://api.spotify.com/v1/users/xom5ul5f9g6lx...
#
#                     owner.id owner.type  \
# 0                        NaN        NaN
# 1                        NaN        NaN
# 2                        NaN        NaN
# 3                        NaN        NaN
# 4                        NaN        NaN
# 5                        NaN        NaN
# 6                        NaN        NaN
# 7                        NaN        NaN
# 8                        NaN        NaN
# 9                        NaN        NaN
# 0              elektroduenda       user
# 1  cxf8i84lez9qp5txydhe82g4g       user
# 2  o90kk72f7l3kerpre1esq2bsn       user
# 3              bradleywsmith       user
# 4           jainaa._.yenserr       user
# 5                taytay92901       user
# 6               juttasurmann       user
# 7  22v66rfshydf744kvxwqwyjnq       user
# 8  53kzdh7uqp7otizf8sith3ri9       user
# 9  xom5ul5f9g6lxfco5q7nzvxva       user
#
#                                 owner.uri  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# 5                                     NaN
# 6                                     NaN
# 7                                     NaN
# 8                                     NaN
# 9                                     NaN
# 0              spotify:user:elektroduenda
# 1  spotify:user:cxf8i84lez9qp5txydhe82g4g
# 2  spotify:user:o90kk72f7l3kerpre1esq2bsn
# 3              spotify:user:bradleywsmith
# 4           spotify:user:jainaa._.yenserr
# 5                spotify:user:taytay92901
# 6               spotify:user:juttasurmann
# 7  spotify:user:22v66rfshydf744kvxwqwyjnq
# 8  spotify:user:53kzdh7uqp7otizf8sith3ri9
# 9  spotify:user:xom5ul5f9g6lxfco5q7nzvxva
#
#                                          tracks.href tracks.total
# 0                                                NaN          NaN
# 1                                                NaN          NaN
# 2                                                NaN          NaN
# 3                                                NaN          NaN
# 4                                                NaN          NaN
# 5                                                NaN          NaN
# 6                                                NaN          NaN
# 7                                                NaN          NaN
# 8                                                NaN          NaN
# 9                                                NaN          NaN
# 0  https://api.spotify.com/v1/playlists/7oIdYroGB...         21.0
# 1  https://api.spotify.com/v1/playlists/2WaqTt9se...         26.0
# 2  https://api.spotify.com/v1/playlists/3bDOB6WgV...         34.0
# 3  https://api.spotify.com/v1/playlists/2CaOL7cJe...        117.0
# 4  https://api.spotify.com/v1/playlists/0i4e1HNsR...         55.0
# 5  https://api.spotify.com/v1/playlists/1QHbLvsWl...         46.0
# 6  https://api.spotify.com/v1/playlists/7el6VJ9QR...         15.0
# 7  https://api.spotify.com/v1/playlists/3lvqb63AM...        321.0
# 8  https://api.spotify.com/v1/playlists/2bGTu4LPo...         10.0
# 9  https://api.spotify.com/v1/playlists/3mpSeSzWj...         32.0
#
# [20 rows x 25 columns]

# %%
df.to_csv("check_avatar.csv", index=False)

# %%
from bs4 import BeautifulSoup

file = pd.read_csv("1990_2020_movie_list1227.csv", encoding='latin1')
titles = file.title.tolist()

searchbase = r"https://www.traileraddict.com/search/"
#search_str = 'Avatar'

res_list = []

for search_str in titles:
    q = urllib.parse.quote(search_str).lower()
    url = searchbase + q
    print(url)
    page = requests.get(url).text

    soup = BeautifulSoup(page, "html.parser")
    res = soup.find_all('div' , class_="info")
    # #lis = res.find_all("li", class_="result")

    for l in res:
        d = {'search': search_str,
             'href': l.find_previous_sibling()['href']}
        for ch in l.find_all('div',recursive=False):
            for cc in ch:
                if len(str(cc))>1:
                    ss = list(cc.stripped_strings)
                    if 'class' in cc.attrs.keys():
                        d[list(cc['class'])[0]] = ss[-1]
                    else:
                        d[ss[0]] = ss[-1]
        res_list.append(d)
# Out:
# https://www.traileraddict.com/search/avatar
# https://www.traileraddict.com/search/titanic
# https://www.traileraddict.com/search/the%20avengers
# https://www.traileraddict.com/search/jurassic%20world
# https://www.traileraddict.com/search/the%20dark%20knight
# https://www.traileraddict.com/search/star%20wars%3a%20episode%20i%20-%20the%20phantom%20menace
# https://www.traileraddict.com/search/avengers%3a%20age%20of%20ultron
# https://www.traileraddict.com/search/the%20dark%20knight%20rises
# https://www.traileraddict.com/search/shrek%202
# https://www.traileraddict.com/search/the%20hunger%20games%3a%20catching%20fire
# https://www.traileraddict.com/search/pirates%20of%20the%20caribbean%3a%20dead%20man%27s%20chest
# https://www.traileraddict.com/search/the%20lion%20king
# https://www.traileraddict.com/search/toy%20story%203
# https://www.traileraddict.com/search/iron%20man%203
# https://www.traileraddict.com/search/the%20hunger%20games
# https://www.traileraddict.com/search/spider-man
# https://www.traileraddict.com/search/jurassic%20park
# https://www.traileraddict.com/search/transformers%3a%20revenge%20of%20the%20fallen
# https://www.traileraddict.com/search/frozen
# https://www.traileraddict.com/search/harry%20potter%20and%20the%20deathly%20hallows%3a%20part%202
# https://www.traileraddict.com/search/finding%20nemo
# https://www.traileraddict.com/search/star%20wars%3a%20episode%20iii%20-%20revenge%20of%20the%20sith
# https://www.traileraddict.com/search/the%20lord%20of%20the%20rings%3a%20the%20return%20of%20the%20king
# https://www.traileraddict.com/search/spider-man%202
# https://www.traileraddict.com/search/despicable%20me%202
# https://www.traileraddict.com/search/transformers%3a%20dark%20of%20the%20moon
# https://www.traileraddict.com/search/american%20sniper
# https://www.traileraddict.com/search/furious%20seven
# https://www.traileraddict.com/search/the%20lord%20of%20the%20rings%3a%20the%20two%20towers
# https://www.traileraddict.com/search/the%20hunger%20games%3a%20mockingjay%20-%20part%201
# https://www.traileraddict.com/search/spider-man%203
# https://www.traileraddict.com/search/alice%20in%20wonderland
# https://www.traileraddict.com/search/guardians%20of%20the%20galaxy
# https://www.traileraddict.com/search/forrest%20gump
# https://www.traileraddict.com/search/shrek%20the%20third
# https://www.traileraddict.com/search/transformers
# https://www.traileraddict.com/search/iron%20man
# https://www.traileraddict.com/search/harry%20potter%20and%20the%20sorcerer%27s%20stone
# https://www.traileraddict.com/search/indiana%20jones%20and%20the%20kingdom%20of%20the%20crystal%20skull
# https://www.traileraddict.com/search/the%20lord%20of%20the%20rings%3a%20the%20fellowship%20of%20the%20ring
# https://www.traileraddict.com/search/iron%20man%202
# https://www.traileraddict.com/search/star%20wars%3a%20episode%20ii%20-%20attack%20of%20the%20clones
# https://www.traileraddict.com/search/pirates%20of%20the%20caribbean%3a%20at%20world%27s%20end
# https://www.traileraddict.com/search/independence%20day
# https://www.traileraddict.com/search/pirates%20of%20the%20caribbean%3a%20the%20curse%20of%20the%20black%20pearl
# https://www.traileraddict.com/search/skyfall
# https://www.traileraddict.com/search/the%20hobbit%3a%20an%20unexpected%20journey
# https://www.traileraddict.com/search/harry%20potter%20and%20the%20half-blood%20prince
# https://www.traileraddict.com/search/the%20twilight%20saga%3a%20eclipse
# https://www.traileraddict.com/search/the%20twilight%20saga%3a%20new%20moon
# https://www.traileraddict.com/search/harry%20potter%20and%20the%20deathly%20hallows%3a%20part%201
# https://www.traileraddict.com/search/the%20sixth%20sense
# https://www.traileraddict.com/search/up
# https://www.traileraddict.com/search/inception
# https://www.traileraddict.com/search/the%20twilight%20saga%3a%20breaking%20dawn%20-%20part%202
# https://www.traileraddict.com/search/harry%20potter%20and%20the%20order%20of%20the%20phoenix
# https://www.traileraddict.com/search/the%20chronicles%20of%20narnia%3a%20the%20lion%2c%20the%20witch%20and%20the%20wardrobe
# https://www.traileraddict.com/search/man%20of%20steel
# https://www.traileraddict.com/search/harry%20potter%20and%20the%20goblet%20of%20fire
# https://www.traileraddict.com/search/monsters%2c%20inc.
# https://www.traileraddict.com/search/inside%20out
# https://www.traileraddict.com/search/home%20alone
# https://www.traileraddict.com/search/the%20matrix%20reloaded
# https://www.traileraddict.com/search/the%20twilight%20saga%3a%20breaking%20dawn%20-%20part%201
# https://www.traileraddict.com/search/meet%20the%20fockers
# https://www.traileraddict.com/search/the%20hangover
# https://www.traileraddict.com/search/gravity
